# %% [markdown]
# ###Install Dependencies###

# %%
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 76.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ###Configure Kaggle Credentials###

# %%
import os

os.environ["KAGGLE_USERNAME"] = "dpathak2702"
os.environ["KAGGLE_KEY"] = "6cbf6295549a17371ff3b2e92e4071b0"

print("Kaggle credentials configured!")
# Out:
# Kaggle credentials configured!

# %% [markdown]
# ###Create Database Schema###

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")
# Out:
# DataFrame[]

# %% [markdown]
# ###Create Volume for Data Storage

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")
# Out:
# DataFrame[]

# %% [markdown]
# ###Download Dataset from Kaggle

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store
# License(s): copyright-authors
# ...
# 100%|██████████| 4.29G/4.29G [00:26<00:00, 176MB/s]

# %% [markdown]
# ###Extract Downloaded Dataset

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
unzip -o ecommerce-behavior-data-from-multi-category-store.zip
ls -lh
# Out:
# Archive:  ecommerce-behavior-data-from-multi-category-store.zip
#   inflating: 2019-Nov.csv
#   inflating: 2019-Oct.csv
# total 18G
# -rwxrwxrwx 1 spark-efb59ca2-c944-45f9-898a-8e nogroup 8.4G Jan 12 08:11 2019-Nov.csv
# -rwxrwxrwx 1 spark-efb59ca2-c944-45f9-898a-8e nogroup 5.3G Jan 12 08:14 2019-Oct.csv
# -rwxrwxrwx 1 spark-efb59ca2-c944-45f9-898a-8e nogroup 4.3G Jan 12 08:09 ecommerce-behavior-data-from-multi-category-store.zip

# %% [markdown]
# ###Clean Up Zip File

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
rm -f ecommerce-behavior-data-from-multi-category-store.zip
ls -lh
# Out:
# total 14G
# -rwxrwxrwx 1 spark-efb59ca2-c944-45f9-898a-8e nogroup 8.4G Jan 12 08:11 2019-Nov.csv
# -rwxrwxrwx 1 spark-efb59ca2-c944-45f9-898a-8e nogroup 5.3G Jan 12 08:14 2019-Oct.csv

# %% [markdown]
# ###Restart Python Enviroment

# %%
# %restart_python

# %% [markdown]
# ###Load Nov 2019 Data

# %%
df_n = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv",header=True)

# %% [markdown]
# ###Load Oct 2019 Data

# %%
df_o = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",header=True)

# %% [markdown]
# ###Display Dataset Statistics and Schema

# %% [markdown]
# ###Oct-2019

# %%
print(f"October 2019 - Total Events: {df_o.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df_o.printSchema()
# Out:
# October 2019 - Total Events: 42,448,764
#
# ...
# SCHEMA:
# ...
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)

# %% [markdown]
# ###Nov-2019

# %%
print(f"October 2019 - Total Events: {df_n.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df_n.printSchema()
# Out:
# October 2019 - Total Events: 67,501,979
#
# ...
# SCHEMA:
# ...
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)

# %% [markdown]
# ###Oct Sample Data

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
df_o.show(5, truncate=False)
# Out:
# ...
# SAMPLE DATA (First 5 rows):
# ...
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code                      |brand   |price  |user_id  |user_session                        |
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |2019-10-01 00:00:00 UTC|view      |44600062  |2103807459595387724|NULL                               |shiseido|35.79  |541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# |2019-10-01 00:00:00 UTC|view      |3900821   |2053013552326770905|appliances.environment.water_heater|aqua    |33.20  |554748717|9333dfbd-b87a-4708-9857-6336556b0fcc|
# ...

# %% [markdown]
# ###Nov Sample Data

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
df_n.show(5, truncate=False)
# Out:
# ...
# SAMPLE DATA (First 5 rows):
# ...
# +-----------------------+----------+----------+-------------------+-------------------------+------+------+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code            |brand |price |user_id  |user_session                        |
# +-----------------------+----------+----------+-------------------+-------------------------+------+------+---------+------------------------------------+
# |2019-11-01 00:00:00 UTC|view      |1003461   |2053013555631882655|electronics.smartphone   |xiaomi|489.07|520088904|4d3b30da-a5e4-49df-b1a8-ba5943f1dd33|
# |2019-11-01 00:00:00 UTC|view      |5000088   |2053013566100866035|appliances.sewing_machine|janome|293.65|530496790|8e5f4f83-366c-4f70-860e-ca7417414283|
# |2019-11-01 00:00:01 UTC|view      |17302664  |2053013553853497655|NULL                     |creed |28.31 |561587266|755422e7-9040-477b-9bd2-6a6e8fd97387|
# ...
